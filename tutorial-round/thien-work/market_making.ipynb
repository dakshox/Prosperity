# %% [markdown]
# ## Analysis of market making feasibility on amethyst

# %%
import tools.log_parser as log_parser
import tools.backtester as backtester
import trade_analyzer
import sys
from datamodel import *
import collections
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from dataclasses import dataclass
import math

# %%
sns.set_theme(style="whitegrid")

# %%
LOG_PATH = "03_19_combined_trader.log"

LIMITS = backtester.KNOWN_LIMITS

# %%
log = log_parser.parse_log(LOG_PATH, parse_trader_log_as_object=True)
trade_analyzer.annotate_log(log)
sandbox_logs = log.sandbox_logs
activity_df = log.activity_df

# %%
STARFRUIT = "STARFRUIT"

# %% [markdown]
# Baseline: combined_trader.py

# %%
import combined_trader

# %%
def combined_trader_func(*args, **kwargs):
    orders, conv, trader_data = combined_trader.Trader().run(*args, **kwargs)
    orders[STARFRUIT] = []
    return orders, conv, trader_data

# %%
combined_trader_results = backtester.backtest(combined_trader_func, log)

# %%
combined_trader_results
# Out:
# BacktestResults(balance=-158656, position={'AMETHYSTS': 16}, profit=1344.0)

# %% [markdown]
# Looking for a model of distribution of good bot trades

# %%
def calc_ema(series, alpha):
    # let's do something stupider
    cur = series.iloc[0]
    result = [cur]
    for value in series.iloc[1:]:
        cur = alpha * value + (1 - alpha) * cur
        result.append(cur)
    return pd.Series(result, index=series.index)

# %%
activity_df.columns
# Out:
# Index(['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1',
#        'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3',
#        'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2',
#        'ask_price_3', 'ask_volume_3', 'mid_price', 'profit_and_loss',
#        'position'],
#       dtype='object')

# %%
starfruit_df = activity_df[activity_df["product"] == STARFRUIT]

# %%
starfruit_df["ema_0.1"] = calc_ema(starfruit_df["mid_price"], 0.1)
sns.lineplot(data=starfruit_df, x="timestamp", y="mid_price", errorbar=None, label="mid_price")
sns.lineplot(data=starfruit_df, x="timestamp", y="ema_0.1", errorbar=None, label="ema 0.1")
plt.legend()
plt.xlim(50000, 70000)
# Out:
# C:\Users\Thien\AppData\Local\Temp\ipykernel_16176\3005488956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   starfruit_df["ema_0.1"] = calc_ema(starfruit_df["mid_price"], 0.1)
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (50000.0, 70000.0)

# %%
sns.lineplot(data=starfruit_df, x="timestamp", y="position", errorbar=None, label="position")
plt.legend(loc="upper left")
plt.title("starfruit position vs price")
ax2=plt.twinx()
sns.lineplot(data=starfruit_df, x="timestamp", y="mid_price", errorbar=None, label="mid_price", ax=ax2, color="orange")
ax2.grid(False)
ax2.legend(loc="upper right")
# Out:
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=log.activity_df[log.activity_df["product"]=="AMETHYSTS"], x="timestamp", y="mid_price", errorbar=None, label="mid_price", color="orange")
plt.legend(loc="upper left")
plt.title("amethyst position vs price")
ax2=plt.twinx()
sns.lineplot(data=log.activity_df[log.activity_df["product"]=="AMETHYSTS"], x="timestamp", y="position", errorbar=None, label="position", ax=ax2)
ax2.grid(False)
ax2.legend(loc="upper right")
# Out:
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
starfruit_trades_df = log.trades_df[log.trades_df.symbol==STARFRUIT]
display(starfruit_trades_df.describe(), starfruit_trades_df.head(5))
# Out:
#            timestamp        price    quantity  market_order_filled
# count     804.000000   804.000000  804.000000           419.000000
# mean   100508.830846  4979.850746    3.588308             0.384248
# std     56176.771427    14.142228    4.883032             1.063910
# min         0.000000  4948.000000    1.000000             0.000000
# 25%     52050.000000  4967.000000    1.000000             0.000000
# 50%     99150.000000  4984.000000    1.000000             0.000000
# 75%    147300.000000  4991.000000    4.000000             0.000000
# max    199600.000000  5005.000000   40.000000             8.000000
#     timestamp       buyer      seller     symbol   currency  price  quantity  \
# 0           0                          STARFRUIT  SEASHELLS   5003         1
# 2           0                          STARFRUIT  SEASHELLS   5003        13
# 3         500  SUBMISSION              STARFRUIT  SEASHELLS   5000        20
# 7        1700              SUBMISSION  STARFRUIT  SEASHELLS   5000         9
# 10       1900                          STARFRUIT  SEASHELLS   5002         1
#
#    submission_involved  market_order_filled
# 0                  NaN                  NaN
# 2                  NaN                  NaN
# 3                 True                  0.0
# 7                 True                  0.0
# 10                 NaN                  NaN

# %%
own_starfruit_trades_df = starfruit_trades_df[starfruit_trades_df["submission_involved"] == True]
own_starfruit_trades_df.head()
# Out:
#     timestamp       buyer      seller     symbol   currency  price  quantity  \
# 3         500  SUBMISSION              STARFRUIT  SEASHELLS   5000        20
# 7        1700              SUBMISSION  STARFRUIT  SEASHELLS   5000         9
# 15       3000              SUBMISSION  STARFRUIT  SEASHELLS   5000         1
# 18       3100  SUBMISSION              STARFRUIT  SEASHELLS   4998         2
# 19       3200  SUBMISSION              STARFRUIT  SEASHELLS   4998         2
#
#    submission_involved  market_order_filled
# 3                 True                  0.0
# 7                 True                  0.0
# 15                True                  0.0
# 18                True                  0.0
# 19                True                  0.0

# %%
starfruit_buys = own_starfruit_trades_df[own_starfruit_trades_df["buyer"] == "SUBMISSION"]
starfruit_sells = own_starfruit_trades_df[own_starfruit_trades_df["seller"] == "SUBMISSION"]

# %%
def split_market_orders(trades_df: pd.DataFrame):
    trades_df = trades_df.copy()
    trades_df["limit_order_filled"] = trades_df["quantity"] - trades_df["market_order_filled"]
    trades_df = trades_df.melt(["timestamp", "buyer", "seller", "symbol", "currency", "price", "quantity"], value_vars=["limit_order_filled", "market_order_filled"], var_name="order_type", value_name="order_filled")
    return trades_df

starfruit_buy_market_orders = split_market_orders(starfruit_buys)
starfruit_sell_market_orders = split_market_orders(starfruit_sells)

display(starfruit_buy_market_orders.head(), starfruit_sell_market_orders.head())
# Out:
#    timestamp       buyer seller     symbol   currency  price  quantity  \
# 0        500  SUBMISSION         STARFRUIT  SEASHELLS   5000        20
# 1       3100  SUBMISSION         STARFRUIT  SEASHELLS   4998         2
# 2       3200  SUBMISSION         STARFRUIT  SEASHELLS   4998         2
# 3       3800  SUBMISSION         STARFRUIT  SEASHELLS   4998         6
# 4       4700  SUBMISSION         STARFRUIT  SEASHELLS   4998         7
#
#            order_type  order_filled
# 0  limit_order_filled          20.0
# 1  limit_order_filled           2.0
# 2  limit_order_filled           2.0
# 3  limit_order_filled           6.0
# 4  limit_order_filled           7.0
#    timestamp buyer      seller     symbol   currency  price  quantity  \
# 0       1700        SUBMISSION  STARFRUIT  SEASHELLS   5000         9
# 1       3000        SUBMISSION  STARFRUIT  SEASHELLS   5000         1
# 2       3800        SUBMISSION  STARFRUIT  SEASHELLS   5000        34
# 3       3900        SUBMISSION  STARFRUIT  SEASHELLS   5000         6
# 4       4800        SUBMISSION  STARFRUIT  SEASHELLS   5000         2
#
#            order_type  order_filled
# 0  limit_order_filled           9.0
# 1  limit_order_filled           1.0
# 2  limit_order_filled          34.0
# 3  limit_order_filled           6.0
# 4  limit_order_filled           2.0

# %%
plt.figure(figsize=(20, 12))
sns.lineplot(data=starfruit_df, x="timestamp", y="bid_price_1", errorbar=None, label="bid_price_1", alpha=0.1, color="green")
sns.lineplot(data=starfruit_df, x="timestamp", y="ask_price_1", errorbar=None, label="ask_price_1", alpha=0.1, color="red")
sns.lineplot(data=starfruit_df, x="timestamp", y="mid_price", errorbar=None, label="mid_price", alpha=0.5)
sns.lineplot(data=starfruit_df, x="timestamp", y="ema_0.1", errorbar=None, label="ema 0.1")
sns.scatterplot(data=starfruit_buy_market_orders, x="timestamp", y="price", size="quantity", label="buys", color="green", style="order_type", size_norm=(0, 40), sizes=(10, 50))
sns.scatterplot(data=starfruit_sell_market_orders, x="timestamp", y="price", size="quantity", label="sells", color="red", style="order_type", size_norm=(0, 40), sizes=(10, 50))
# Out:
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timestamp', ylabel='bid_price_1'>

# %%
good_bids = starfruit_df.query("bid_price_1 >= `ema_0.1`")
good_offers = starfruit_df.query("ask_price_1 <= `ema_0.1`")
display(good_bids, good_offers)
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 106    -2       5300  STARFRUIT         5002             1       4997.0
# 112    -2       5600  STARFRUIT         5002             2       4998.0
# 140    -2       7000  STARFRUIT         5002             4       4997.0
# 199    -2       9900  STARFRUIT         5001             4       4996.0
# 206    -2      10300  STARFRUIT         5001             1       4997.0
# ...   ...        ...        ...          ...           ...          ...
# 3883   -2     194100  STARFRUIT         4957             1       4952.0
# 3921   -2     196000  STARFRUIT         4956             1       4951.0
# 3931   -2     196500  STARFRUIT         4956             1       4951.0
# 3948   -2     197400  STARFRUIT         4955             1       4951.0
# 3970   -2     198500  STARFRUIT         4954             1       4949.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 106           21.0          NaN           NaN         5004            21
# 112           28.0          NaN           NaN         5005            28
# 140           27.0          NaN           NaN         5004            27
# 199           25.0          NaN           NaN         5003            25
# 206            8.0       4996.0          27.0         5003            27
# ...            ...          ...           ...          ...           ...
# 3883          25.0          NaN           NaN         4959            25
# 3921          22.0          NaN           NaN         4958            22
# 3931          27.0          NaN           NaN         4958            27
# 3948           8.0       4950.0          20.0         4957            20
# 3970          22.0          NaN           NaN         4956            22
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 106           NaN           NaN          NaN           NaN     5003.0
# 112           NaN           NaN          NaN           NaN     5003.5
# 140           NaN           NaN          NaN           NaN     5003.0
# 199           NaN           NaN          NaN           NaN     5002.0
# 206           NaN           NaN          NaN           NaN     5002.0
# ...           ...           ...          ...           ...        ...
# 3883          NaN           NaN          NaN           NaN     4958.0
# 3921          NaN           NaN          NaN           NaN     4957.0
# 3931          NaN           NaN          NaN           NaN     4957.0
# 3948          NaN           NaN          NaN           NaN     4956.0
# 3970          NaN           NaN          NaN           NaN     4955.0
#
#       profit_and_loss  position      ema_0.1
# 106         29.453125       -15  5000.369171
# 112         16.500000       -16  5000.623626
# 140         30.554688       -20  5001.349912
# 199         45.750000       -20  5000.869234
# 206         63.765625       -20  5000.599305
# ...               ...       ...          ...
# 3883      2011.164062       -20  4956.991513
# 3921      2047.308594       -13  4954.889570
# 3931      2046.585938       -20  4954.829782
# 3948      2070.085938       -20  4954.385966
# 3970      2085.812500       -20  4953.316825
#
# [166 rows x 19 columns]
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 86     -2       4300  STARFRUIT         4998             7       4997.0
# 94     -2       4700  STARFRUIT         4997            32          NaN
# 213    -2      10600  STARFRUIT         4997            31          NaN
# 234    -2      11700  STARFRUIT         4997            23          NaN
# 237    -2      11800  STARFRUIT         4997            29          NaN
# ...   ...        ...        ...          ...           ...          ...
# 3800   -2     190000  STARFRUIT         4954            26          NaN
# 3887   -2     194300  STARFRUIT         4952            30          NaN
# 3977   -2     198800  STARFRUIT         4948            28          NaN
# 3978   -2     198900  STARFRUIT         4949             8       4948.0
# 3988   -2     199400  STARFRUIT         4949            23          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 86            22.0          NaN           NaN         5000             5
# 94             NaN          NaN           NaN         4998             7
# 213            NaN          NaN           NaN         5000             4
# 234            NaN          NaN           NaN         4998             2
# 237            NaN          NaN           NaN         5000             4
# ...            ...          ...           ...          ...           ...
# 3800           NaN          NaN           NaN         4955             9
# 3887           NaN          NaN           NaN         4953             1
# 3977           NaN          NaN           NaN         4949             1
# 3978          27.0          NaN           NaN         4950             5
# 3988           NaN          NaN           NaN         4950             4
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 86         5004.0          22.0          NaN           NaN     4999.0
# 94         5002.0           3.0       5003.0           2.0     4997.5
# 213        5002.0           4.0       5004.0          31.0     4998.5
# 234        5003.0           2.0       5004.0          21.0     4997.5
# 237        5004.0          29.0          NaN           NaN     4998.5
# ...           ...           ...          ...           ...        ...
# 3800       4961.0          26.0          NaN           NaN     4954.5
# 3887       4959.0          30.0          NaN           NaN     4952.5
# 3977       4955.0          28.0          NaN           NaN     4948.5
# 3978       4955.0          27.0          NaN           NaN     4949.5
# 3988       4955.0           1.0       4956.0          22.0     4949.5
#
#       profit_and_loss  position      ema_0.1
# 86           9.328125       -20  5000.060512
# 94          16.632812       -20  4999.830652
# 213         31.843750       -20  5000.241893
# 234         41.398438       -18  5000.370781
# 237         35.000000       -16  5000.183703
# ...               ...       ...          ...
# 3800      1916.445312       -20  4956.921872
# 3887      2011.203125       -20  4956.453126
# 3977      2103.148438       -20  4952.524465
# 3978      2104.289062       -19  4952.222019
# 3988      2109.898438       -16  4951.823140
#
# [151 rows x 19 columns]

# %%
sns.histplot(good_bids, x="timestamp", bins=20)
# Out:
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timestamp', ylabel='Count'>

# %%
sns.stripplot(good_bids, x="timestamp", label="good_bids")
sns.stripplot(good_offers, x="timestamp", label="good_offers")
plt.legend()
# Out:
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thien\miniconda3\envs\kaggle\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
good_bids["diff"] = good_bids["bid_price_1"] - good_bids["ema_0.1"]
good_offers["diff"] = good_offers["ask_price_1"] - good_offers["ema_0.1"]

good_transactions = pd.concat([good_bids.assign(is_bid=True, volume=good_bids["bid_volume_1"]), good_offers.assign(is_bid=False, vol=good_offers["ask_volume_1"])]).sort_index()
good_transactions.head()
# Out:
# C:\Users\Thien\AppData\Local\Temp\ipykernel_16176\3633148502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_bids["diff"] = good_bids["bid_price_1"] - good_bids["ema_0.1"]
# C:\Users\Thien\AppData\Local\Temp\ipykernel_16176\3633148502.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_offers["diff"] = good_offers["ask_price_1"] - good_offers["ema_0.1"]
#      day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 86    -2       4300  STARFRUIT         4998             7       4997.0
# 94    -2       4700  STARFRUIT         4997            32          NaN
# 106   -2       5300  STARFRUIT         5002             1       4997.0
# 112   -2       5600  STARFRUIT         5002             2       4998.0
# 140   -2       7000  STARFRUIT         5002             4       4997.0
#
#      bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ...  ask_price_3  \
# 86           22.0          NaN           NaN         5000  ...          NaN
# 94            NaN          NaN           NaN         4998  ...       5003.0
# 106          21.0          NaN           NaN         5004  ...          NaN
# 112          28.0          NaN           NaN         5005  ...          NaN
# 140          27.0          NaN           NaN         5004  ...          NaN
#
#      ask_volume_3  mid_price  profit_and_loss  position      ema_0.1  \
# 86            NaN     4999.0         9.328125       -20  5000.060512
# 94            2.0     4997.5        16.632812       -20  4999.830652
# 106           NaN     5003.0        29.453125       -15  5000.369171
# 112           NaN     5003.5        16.500000       -16  5000.623626
# 140           NaN     5003.0        30.554688       -20  5001.349912
#
#          diff  is_bid  volume  vol
# 86  -0.060512   False     NaN  5.0
# 94  -1.830652   False     NaN  7.0
# 106  1.630829    True     1.0  NaN
# 112  1.376374    True     2.0  NaN
# 140  0.650088    True     4.0  NaN
#
# [5 rows x 23 columns]

# %%
good_bids["diff"] = good_bids["bid_price_1"] - good_bids["ema_0.1"]
good_offers["diff"] = good_offers["ask_price_1"] - good_offers["ema_0.1"]
sns.scatterplot(data=good_bids, x="timestamp", y="diff", size="bid_volume_1", legend="brief", size_norm=(1, 2))
sns.scatterplot(data=good_offers, x="timestamp", y="diff", size="ask_volume_1", legend=False, size_norm=(1, 2))
# Out:
# C:\Users\Thien\AppData\Local\Temp\ipykernel_16176\4044792808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_bids["diff"] = good_bids["bid_price_1"] - good_bids["ema_0.1"]
# C:\Users\Thien\AppData\Local\Temp\ipykernel_16176\4044792808.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_offers["diff"] = good_offers["ask_price_1"] - good_offers["ema_0.1"]
# <Axes: xlabel='timestamp', ylabel='diff'>

# %%
a = (good_bids["diff"] * good_bids["bid_volume_1"])
b = (good_offers["diff"] * good_offers["ask_volume_1"])
print(a.sum() - b.sum())
# Out:
# 1300.1484899177894

# %%
class EMA:
    def __init__(self, alpha: float):
        self.alpha = alpha
        self.ema = None
        self.last_value = None
        self.history = []

    def update(self, new_value: float | None):
        if new_value is None:
            new_value = self.last_value
        if new_value is None:
            return
        if self.ema is None:
            self.ema = new_value
        else:
            self.ema = self.alpha * new_value + (1 - self.alpha) * self.ema
        self.last_value = new_value
        self.history.append(self.ema)
